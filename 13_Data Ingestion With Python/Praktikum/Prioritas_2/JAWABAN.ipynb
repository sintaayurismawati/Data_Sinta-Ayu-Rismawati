# %%
! pip list
# Out:
# Package            Version
# ------------------ -----------
# asttokens          2.4.1
# beautifulsoup4     4.12.3
# certifi            2024.2.2
# charset-normalizer 3.3.2
# colorama           0.4.6
# comm               0.2.2
# debugpy            1.8.1
# decorator          5.1.1
# distlib            0.3.8
# et-xmlfile         1.1.0
# executing          2.0.1
# filelock           3.13.3
# idna               3.7
# ipykernel          6.29.4
# ipython            8.23.0
# jedi               0.19.1
# jupyter_client     8.6.1
# jupyter_core       5.7.2
# matplotlib-inline  0.1.6
# nest-asyncio       1.6.0
# numpy              1.26.4
# openpyxl           3.1.2
# packaging          24.0
# pandas             2.2.2
# parso              0.8.4
# pip                24.0
# platformdirs       4.2.0
# prompt-toolkit     3.0.43
# psutil             5.9.8
# pure-eval          0.2.2
# pyarrow            15.0.2
# Pygments           2.17.2
# PyMySQL            1.1.0
# python-dateutil    2.9.0.post0
# ...

# %%
! pip install beautifulsoup4
# Out:
# ...
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/147.9 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 147.9/147.9 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://somethinc.com/en/collection/skincare"
response = requests.get(url)
html = BeautifulSoup(response.content, 'html.parser')
print(html)
# Out:
# b'<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n\t<meta charset="utf-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0" />\n\t\n\t<title>Buy SOMETHINC Skincare Original Best Deals</title>\n\t<meta name="description" content="Get various product SOMETHINC Skincare with Best Deals | #1 Local Beauty Brand | Original | BPOM | Halal" />\n\t\t<link rel="shortcut icon" type="image/x-icon" href="https://somethinc.com/assets/favicon111.ico" />\n    <link rel="canonical" href="https://somethinc.com/en/collection/skincare" />\n\n\t\n        <meta property="og:url" content="https://somethinc.com/en/collection/skincare">\n\t<meta property="og:title" content="Buy SOMETHINC Skincare Original Best Deals" />\n    <meta property="og:description" content="Get various product SOMETHINC Skincare with Best Deals | #1 Local Beauty Brand | Original | BPOM | Halal" />\n    <meta prop
# ...
